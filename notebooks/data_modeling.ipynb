# %% [markdown]
# # Data Modeling
#
# **Ojective:** Train and store optimized regression models for each currency pair, Build a new dictionary for parsing VOL and FD.
#
# 1. Combine and clean 40 hours of the past currency datasets, and use 400 data points for model training.
# 2. Loop through each currency pair, train and store models in the **models** folder.
# 3. Within the loop, build the dictionary for the trailing stops use.

# %%
# Import required libraries
import datetime
import time
from polygon import RESTClient
from sqlalchemy import create_engine 
from sqlalchemy import text
import pandas as pd
from math import sqrt
from math import isnan
import matplotlib.pyplot as plt
from numpy import mean
from numpy import std
from math import floor
import numpy as np
import pandas as pd

# import pycaret
from pycaret.regression import *

# %%
currency_pairs = [["EUR","USD",[], []],
                  ["GBP","USD",[], []],
                  ["USD","CHF",[], []],
                  ["USD","CAD",[], []],
                  ["USD","HKD",[], []],
                  ["USD","AUD",[], []],
                  ["USD","NZD",[], []],
                  ["USD","SGD",[], []]]

# %%
# define a dictionary that we are going to use for storing sorted vol and fd parsing

dic_vol = {}
dic_fd = {}

# %%
# create engine to connect with 4 currency pairs database. 

engine1 = create_engine("sqlite+pysqlite:///../data/day1.db", echo=False, future=True)
engine2 = create_engine("sqlite+pysqlite:///../data/trailing.db", echo=False, future=True)
engine3 = create_engine("sqlite+pysqlite:///../data/day1_unclean.db", echo=False, future=True)
engine4 = create_engine("sqlite+pysqlite:///../data/day2_unclean.db", echo=False, future=True)

# %% [markdown]
# ## Individual Sort Method

# %%
# create connections with 4 database, combine them and create regression models out of 40 hours of data.
with engine1.connect() as conn1:
    with engine2.connect() as conn2:
        with engine3.connect() as conn3:
            with engine4.connect() as conn4:
                for curr in currency_pairs:
                    df1 = pd.read_sql_table(curr[0]+curr[1]+"_agg",conn1)
                    df2 = pd.read_sql_table(curr[0]+curr[1]+"_agg",conn2)
                    df3 = pd.read_sql_table(curr[0]+curr[1]+"_agg",conn3)
                    df4 = pd.read_sql_table(curr[0]+curr[1]+"_agg",conn4)
                # clean up database1 and put in a dataframe
                    df1 = df1[['avgfxrate', 'vol','fd','return_r']]
                    df1 = df1.iloc[1:]
                    df1= df1.reset_index(drop=True)
                # clean up database2 and put in a dataframe
                    df2 = df2[['avgfxrate', 'vol','fd','return_r']]
                    df2 = df2.iloc[1:]
                    df2= df2.reset_index(drop=True) 
                # clean up database3 and put in a dataframe (VOL database3 is unconverted, and need to divide them by the mean)
                    df3 = df3[['avgfxrate', 'vol','fd','return_r']]
                    df3 = df3.iloc[1:]
                    df3= df3.reset_index(drop=True)
                    # change the VOL
                    df3['vol'] = df3['vol']/df3['avgfxrate']
                # clean up database4 and put in a dataframe (VOL database3 is unconverted, and need to divide them by the mean)
                    df4 = df4[['avgfxrate', 'vol','fd','return_r']]
                    df4 = df4.iloc[1:]
                    df4= df4.reset_index(drop=True)
                    # change the VOL
                    df4['vol'] = df4['vol']/df4['avgfxrate']
           
                # concatenate 4 database into our training dataframe
                    training = pd.concat([df1, df2,df3, df4], ignore_index=True)
                   
                # sort the traning set by vol and fd
                    training_vol = training.sort_values(by=['vol'], ascending=True)
                    training_vol.reset_index(drop=True, inplace=True)

                    training_fd = training.sort_values(by=['fd'], ascending=True)
                    training_fd.reset_index(drop=True, inplace=True)

                # init two varibale threshold 1 and 2 to note down the two breaking point, and put into the dictionary.
                    thres1_vol = training_vol['vol'][132]
                    thres2_vol = training_vol['vol'][264]

                    thres1_fd = training_fd['fd'][132]
                    thres2_fd = training_fd['fd'][264]
                
                # put threshold into dictionaries
                    dic_vol[curr[0]+curr[1]] = [thres1_vol, thres1_vol]
                    dic_fd[curr[0]+curr[1]] = [thres1_fd, thres2_fd]

                # define a function to put a new series to our training datasets
                    def parse_vol(series):
                        global thres1_vol
                        global thres2_vol
                        if series <= thres1_vol:
                            return 1
                        if series <= thres2_vol:
                            return 2
                        else:
                            return 3

                    def parse_fd(series):
                        global thres1_fd
                        global thres2_fd
                        if series <= thres1_fd:
                            return 1
                        if series <= thres2_fd:
                            return 2
                        else:
                            return 3

                    training['vol_rank'] = training['vol'].apply(parse_vol)
                    training['fd_rank'] = training['fd'].apply(parse_fd)

                # After coding to vol and fd in to [1,2,3], we need multiple the reurn by 100,000 to normalize the training output
                    training['return_r_label'] = training['return_r'].apply(lambda x: x * 100000)

                
                # Assign to our newly proccessed training dataset
                    training = training[['avgfxrate', 'vol_rank', 'fd_rank','return_r_label']]

                # we will init our categorical features and numeric features into a list
                    cate_features = ['vol_rank','fd_rank']
                    num_features = ['avgfxrate']

                # Now starting to model with Pycaret regression 
                    s = setup(data=training, target='return_r_label', categorical_features=cate_features, numeric_features=num_features)
                # we have to exclude the following regression models because they don't generate predictions. 
                    best = compare_models(exclude=['llar','dummy','lasso', 'en'])
                    evaluate_model(best)
                # save the model
                    save_model(best,f'../models/{curr[0]}{curr[1]}')
# Out:
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# <style type="text/css">
# #T_3b567_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3b567">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b567_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3b567_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b567_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3b567_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3b567_row0_col1" class="data row0 col1" >3245</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3b567_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3b567_row1_col1" class="data row1 col1" >return_r_label</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3b567_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3b567_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3b567_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_3b567_row3_col1" class="data row3 col1" >(396, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3b567_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_3b567_row4_col1" class="data row4 col1" >(277, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3b567_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_3b567_row5_col1" class="data row5 col1" >(119, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3b567_row6_col0" class="data row6 col0" >Numeric features</td>
#       <td id="T_3b567_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3b567_row7_col0" class="data row7 col0" >Categorical features</td>
#       <td id="T_3b567_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3b567_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_3b567_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3b567_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_3b567_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3b567_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_3b567_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3b567_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_3b567_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3b567_row12_col0" class="data row12 col0" >Maximum one-hot encoding</td>
#       <td id="T_3b567_row12_col1" class="data row12 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3b567_row13_col0" class="data row13 col0" >Encoding method</td>
#       <td id="T_3b567_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3b567_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_3b567_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3b567_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_3b567_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3b567_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_3b567_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3b567_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_3b567_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3b567_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_3b567_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3b567_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_3b567_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3b567_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3b567_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_3b567_row20_col1" class="data row20 col1" >795c</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_def13 th {
#   text-align: left;
# }
# #T_def13_row0_col0, #T_def13_row0_col5, #T_def13_row1_col0, #T_def13_row1_col1, #T_def13_row1_col2, #T_def13_row1_col3, #T_def13_row1_col4, #T_def13_row1_col5, #T_def13_row1_col6, #T_def13_row2_col0, #T_def13_row2_col1, #T_def13_row2_col2, #T_def13_row2_col3, #T_def13_row2_col4, #T_def13_row2_col5, #T_def13_row2_col6, #T_def13_row3_col0, #T_def13_row3_col1, #T_def13_row3_col2, #T_def13_row3_col3, #T_def13_row3_col4, #T_def13_row3_col5, #T_def13_row3_col6, #T_def13_row4_col0, #T_def13_row4_col1, #T_def13_row4_col2, #T_def13_row4_col3, #T_def13_row4_col4, #T_def13_row4_col5, #T_def13_row4_col6, #T_def13_row5_col0, #T_def13_row5_col1, #T_def13_row5_col2, #T_def13_row5_col3, #T_def13_row5_col4, #T_def13_row5_col5, #T_def13_row5_col6, #T_def13_row6_col0, #T_def13_row6_col1, #T_def13_row6_col2, #T_def13_row6_col3, #T_def13_row6_col4, #T_def13_row6_col5, #T_def13_row6_col6, #T_def13_row7_col0, #T_def13_row7_col1, #T_def13_row7_col2, #T_def13_row7_col3, #T_def13_row7_col4, #T_def13_row7_col5, #T_def13_row7_col6, #T_def13_row8_col0, #T_def13_row8_col1, #T_def13_row8_col2, #T_def13_row8_col3, #T_def13_row8_col4, #T_def13_row8_col5, #T_def13_row8_col6, #T_def13_row9_col0, #T_def13_row9_col1, #T_def13_row9_col2, #T_def13_row9_col3, #T_def13_row9_col4, #T_def13_row9_col5, #T_def13_row9_col6, #T_def13_row10_col0, #T_def13_row10_col1, #T_def13_row10_col2, #T_def13_row10_col3, #T_def13_row10_col4, #T_def13_row10_col5, #T_def13_row10_col6, #T_def13_row11_col0, #T_def13_row11_col1, #T_def13_row11_col2, #T_def13_row11_col3, #T_def13_row11_col4, #T_def13_row11_col5, #T_def13_row11_col6, #T_def13_row12_col0, #T_def13_row12_col1, #T_def13_row12_col2, #T_def13_row12_col3, #T_def13_row12_col4, #T_def13_row12_col6, #T_def13_row13_col0, #T_def13_row13_col1, #T_def13_row13_col2, #T_def13_row13_col3, #T_def13_row13_col4, #T_def13_row13_col5, #T_def13_row13_col6 {
#   text-align: left;
# }
# #T_def13_row0_col1, #T_def13_row0_col2, #T_def13_row0_col3, #T_def13_row0_col4, #T_def13_row0_col6, #T_def13_row12_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_def13_row0_col7, #T_def13_row2_col7, #T_def13_row6_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_def13_row1_col7, #T_def13_row3_col7, #T_def13_row4_col7, #T_def13_row5_col7, #T_def13_row7_col7, #T_def13_row8_col7, #T_def13_row9_col7, #T_def13_row10_col7, #T_def13_row11_col7, #T_def13_row12_col7, #T_def13_row13_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_def13">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_def13_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_def13_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_def13_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_def13_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_def13_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_def13_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_def13_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_def13_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_def13_level0_row0" class="row_heading level0 row0" >br</th>
#       <td id="T_def13_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_def13_row0_col1" class="data row0 col1" >24.5997</td>
#       <td id="T_def13_row0_col2" class="data row0 col2" >1252.7264</td>
#       <td id="T_def13_row0_col3" class="data row0 col3" >34.6862</td>
#       <td id="T_def13_row0_col4" class="data row0 col4" >-0.0462</td>
#       <td id="T_def13_row0_col5" class="data row0 col5" >2.2296</td>
#       <td id="T_def13_row0_col6" class="data row0 col6" >1.7675</td>
#       <td id="T_def13_row0_col7" class="data row0 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_def13_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_def13_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_def13_row1_col1" class="data row1 col1" >24.6074</td>
#       <td id="T_def13_row1_col2" class="data row1 col2" >1254.4057</td>
#       <td id="T_def13_row1_col3" class="data row1 col3" >34.7221</td>
#       <td id="T_def13_row1_col4" class="data row1 col4" >-0.0500</td>
#       <td id="T_def13_row1_col5" class="data row1 col5" >2.1152</td>
#       <td id="T_def13_row1_col6" class="data row1 col6" >2.5522</td>
#       <td id="T_def13_row1_col7" class="data row1 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_def13_level0_row2" class="row_heading level0 row2" >omp</th>
#       <td id="T_def13_row2_col0" class="data row2 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_def13_row2_col1" class="data row2 col1" >24.6417</td>
#       <td id="T_def13_row2_col2" class="data row2 col2" >1254.9656</td>
#       <td id="T_def13_row2_col3" class="data row2 col3" >34.7333</td>
#       <td id="T_def13_row2_col4" class="data row2 col4" >-0.0503</td>
#       <td id="T_def13_row2_col5" class="data row2 col5" >2.0890</td>
#       <td id="T_def13_row2_col6" class="data row2 col6" >2.4462</td>
#       <td id="T_def13_row2_col7" class="data row2 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_def13_level0_row3" class="row_heading level0 row3" >huber</th>
#       <td id="T_def13_row3_col0" class="data row3 col0" >Huber Regressor</td>
#       <td id="T_def13_row3_col1" class="data row3 col1" >24.6649</td>
#       <td id="T_def13_row3_col2" class="data row3 col2" >1257.8110</td>
#       <td id="T_def13_row3_col3" class="data row3 col3" >34.7660</td>
#       <td id="T_def13_row3_col4" class="data row3 col4" >-0.0529</td>
#       <td id="T_def13_row3_col5" class="data row3 col5" >2.0757</td>
#       <td id="T_def13_row3_col6" class="data row3 col6" >2.1064</td>
#       <td id="T_def13_row3_col7" class="data row3 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_def13_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_def13_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_def13_row4_col1" class="data row4 col1" >24.7787</td>
#       <td id="T_def13_row4_col2" class="data row4 col2" >1269.9979</td>
#       <td id="T_def13_row4_col3" class="data row4 col3" >34.9444</td>
#       <td id="T_def13_row4_col4" class="data row4 col4" >-0.0641</td>
#       <td id="T_def13_row4_col5" class="data row4 col5" >2.0537</td>
#       <td id="T_def13_row4_col6" class="data row4 col6" >2.4487</td>
#       <td id="T_def13_row4_col7" class="data row4 col7" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_def13_level0_row5" class="row_heading level0 row5" >lar</th>
#       <td id="T_def13_row5_col0" class="data row5 col0" >Least Angle Regression</td>
#       <td id="T_def13_row5_col1" class="data row5 col1" >24.7787</td>
#       <td id="T_def13_row5_col2" class="data row5 col2" >1269.9980</td>
#       <td id="T_def13_row5_col3" class="data row5 col3" >34.9444</td>
#       <td id="T_def13_row5_col4" class="data row5 col4" >-0.0641</td>
#       <td id="T_def13_row5_col5" class="data row5 col5" >2.0537</td>
#       <td id="T_def13_row5_col6" class="data row5 col6" >2.4487</td>
#       <td id="T_def13_row5_col7" class="data row5 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_def13_level0_row6" class="row_heading level0 row6" >par</th>
#       <td id="T_def13_row6_col0" class="data row6 col0" >Passive Aggressive Regressor</td>
#       <td id="T_def13_row6_col1" class="data row6 col1" >26.0637</td>
#       <td id="T_def13_row6_col2" class="data row6 col2" >1333.8918</td>
#       <td id="T_def13_row6_col3" class="data row6 col3" >35.8801</td>
#       <td id="T_def13_row6_col4" class="data row6 col4" >-0.1320</td>
#       <td id="T_def13_row6_col5" class="data row6 col5" >1.4144</td>
#       <td id="T_def13_row6_col6" class="data row6 col6" >3.9344</td>
#       <td id="T_def13_row6_col7" class="data row6 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_def13_
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# Transformation Pipeline and Model Successfully Saved
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# <style type="text/css">
# #T_a404e_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a404e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a404e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a404e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a404e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a404e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a404e_row0_col1" class="data row0 col1" >8009</td>
#     </tr>
#     <tr>
#       <th id="T_a404e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a404e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a404e_row1_col1" class="data row1 col1" >return_r_label</td>
#     </tr>
#     <tr>
#       <th id="T_a404e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a404e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a404e_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_a404e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a404e_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T
level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_20464_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_20464_row5_col1" class="data row5 col1" >31.7111</td>
#       <td id="T_20464_row5_col2" class="data row5 col2" >1917.2269</td>
#       <td id="T_20464_row5_col3" class="data row5 col3" >43.0095</td>
#       <td id="T_20464_row5_col4" class="data row5 col4" >-0.0826</td>
#       <td id="T_20464_row5_col5" class="data row5 col5" >2.0404</td>
#       <td id="T_20464_row5_col6" class="data row5 col6" >1.2885</td>
#       <td id="T_20464_row5_col7" class="data row5 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_20464_level0_row6" class="row_heading level0 row6" >lightgbm</th>
#       <td id="T_20464_row6_col0" class="data row6 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_20464_row6_col1" class="data row6 col1" >32.4589</td>
#       <td id="T_20464_row6_col2" class="data row6 col2" >1949.6119</td>
#       <td id="T_20464_row6_col3" class="data row6 col3" >43.2585</td>
#       <td id="T_20464_row6_col4" class="data row6 col4" >-0.1053</td>
#       <td id="T_20464_row6_col5" class="data row6 col5" >1.3728</td>
#       <td id="T_20464_row6_col6" class="data row6 col6" >2.2829</td>
#       <td id="T_20464_row6_col7" class="data row6 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# Transformation Pipeline and Model Successfully Saved
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# <style type="text/css">
# #T_900db_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_900db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_900db_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_900db_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_900db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_900db_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_900db_row0_col1" class="data row0 col1" >3924</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_900db_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_900db_row1_col1" class="data row1 col1" >return_r_label</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_900db_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_900db_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_900db_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_900db_row3_col1" class="data row3 col1" >(396, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_900db_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_900db_row4_col1" class="data row4 col1" >(277, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_900db_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_900db_row5_col1" class="data row5 col1" >(119, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_900db_row6_col0" class="data row6 col0" >Numeric features</td>
#       <td id="T_900db_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_900db_row7_col0" class="data row7 col0" >Categorical features</td>
#       <td id="T_900db_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_900db_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_900db_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_900db_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_900db_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_900db_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_900db_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_900db_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_900db_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_900db_row12_col0" class="data row12 col0" >Maximum one-hot encoding</td>
#       <td id="T_900db_row12_col1" class="data row12 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_900db_row13_col0" class="data row13 col0" >Encoding method</td>
#       <td id="T_900db_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_900db_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_900db_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_900db_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_900db_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_900db_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_900db_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_900db_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_900db_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_900db_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_900db_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_900db_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_900db_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_900db_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_900db_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_900db_row20_col1" class="data row20 col1" >5a14</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_455f0 th {
#   text-align: left;
# }
# #T_455f0_row0_col0, #T_455f0_row0_col1, #T_455f0_row0_col5, #T_455f0_row0_col6, #T_455f0_row1_col0, #T_455f0_row1_col2, #T_455f0_row1_col3, #T_455f0_row1_col4, #T_455f0_row1_col5, #T_455f0_row2_col0, #T_455f0_row2_col1, #T_455f0_row2_col2, #T_455f0_row2_col3, #T_455f0_row2_col4, #T_455f0_row2_col5, #T_455f0_row2_col6, #T_455f0_row3_col0, #T_455f0_row3_col1, #T_455f0_row3_col2, #T_455f0_row3_col3, #T_455f0_row3_col4, #T_455f0_row3_col5, #T_455f0_row3_col6, #T_455f0_row4_col0, #T_455f0_row4_col1, #T_455f0_row4_col2, #T_455f0_row4_col3, #T_455f0_row4_col4, #T_455f0_row4_col5, #T_455f0_row4_col6, #T_455f0_row5_col0, #T_455f0_row5_col1, #T_455f0_row5_col2, #T_455f0_row5_col3, #T_455f0_row5_col4, #T_455f0_row5_col5, #T_455f0_row5_col6, #T_455f0_row6_col0, #T_455f0_row6_col1, #T_455f0_row6_col2, #T_455f0_row6_col3, #T_455f0_row6_col4, #T_455f0_row6_col5, #T_455f0_row6_col6, #T_455f0_row7_col0, #T_455f0_row7_col1, #T_455f0_row7_col2, #T_455f0_row7_col3, #T_455f0_row7_col4, #T_455f0_row7_col5, #T_455f0_row7_col6, #T_455f0_row8_col0, #T_455f0_row8_col1, #T_455f0_row8_col2, #T_455f0_row8_col3, #T_455f0_row8_col4, #T_455f0_row8_col5, #T_455f0_row8_col6, #T_455f0_row9_col0, #T_455f0_row9_col1, #T_455f0_row9_col2, #T_455f0_row9_col3, #T_455f0_row9_col4, #T_455f0_row9_col5, #T_455f0_row9_col6, #T_455f0_row10_col0, #T_455f0_row10_col1, #T_455f0_row10_col2, #T_455f0_row10_col3, #T_455f0_row10_col4, #T_455f0_row10_col5, #T_455f0_row10_col6, #T_455f0_row11_col0, #T_455f0_row11_col1, #T_455f0_row11_col2, #T_455f0_row11_col3, #T_455f0_row11_col4, #T_455f0_row11_col5, #T_455f0_row11_col6, #T_455f0_row12_col0, #T_455f0_row12_col1, #T_455f0_row12_col2, #T_455f0_row12_col3, #T_455f0_row12_col4, #T_455f0_row12_col6, #T_455f0_row13_col0, #T_455f0_row13_col1, #T_455f0_row13_col2, #T_455f0_row13_col3, #T_455f0_row13_col4, #T_455f0_row13_col5, #T_455f0_row13_col6 {
#   text-align: left;
# }
# #T_455f0_row0_col2, #T_455f0_row0_col3, #T_455f0_row0_col4, #T_455f0_row1_col1, #T_455f0_row1_col6, #T_455f0_row12_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_455f0_row0_col7, #T_455f0_row2_col7, #T_455f0_row4_col7, #T_455f0_row5_col7, #T_455f0_row7_col7, #T_455f0_row8_col7, #T_455f0_row9_col7, #T_455f0_row10_col7, #T_455f0_row11_col7, #T_455f0_row12_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_455f0_row1_col7, #T_455f0_row3_col7, #T_455f0_row6_col7, #T_455f0_row13_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_455f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_455f0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_455f0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_455f0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_455f0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_455f0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_455f0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_455f0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_455f0_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_455f0_level0_row0" class="row_heading level0 row0" >par</th>
#       <td id="T_455f0_row0_col0" class="data row0 col0" >Passive Aggressive Regressor</td>
#       <td id="T_455f0_row0_col1" class="data row0 col1" >25.5429</td>
#       <td id="T_455f0_row0_col2" class="data row0 col2" >1320.1775</td>
#       <td id="T_455f0_row0_col3" class="data row0 col3" >35.2600</td>
#       <td id="T_455f0_row0_col4" class="data row0 col4" >-0.0348</td>
#       <td id="T_455f0_row0_col5" class="data row0 col5" >1.5964</td>
#       <td id="T_455f0_row0_col6" class="data row0 col6" >5.7538</td>
#       <td id="T_455f0_row0_col7" class="data row0 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_455f0_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_455f0_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_455f0_row1_col1" class="data row1 col1" >25.1371</td>
#       <td id="T_455f0_row1_col2" class="data row1 col2" >1320.3624</td>
#       <td id="T_455f0_row1_col3" class="data row1 col3" >35.3069</td>
#       <td id="T_455f0_row1_col4" class="data row1 col4" >-0.0388</td>
#       <td id="T_455f0_row1_col5" class="data row1 col5" >2.4735</td>
#       <td id="T_455f0_row1_col6" class="data row1 col6" >1.3041</td>
#       <td id="T_455f0_row1_col7" class="data row1 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_455f0_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_455f0_row2_col0" class="data row2 col0" >Ridge Regression</td>
#       <td id="T_455f0_row2_col1" class="data row2 col1" >25.3516</td>
#       <td id="T_455f0_row2_col2" class="data row2 col2" >1332.2874</td>
#       <td id="T_455f0_row2_col3" class="data row2 col3" >35.4798</td>
#       <td id="T_455f0_row2_col4" class="data row2 col4" >-0.0505</td>
#       <td id="T_455f0_row2_col5" class="data row2 col5" >2.1933</td>
#       <td id="T_455f0_row2_col6" class="data row2 col6" >1.8415</td>
#       <td id="T_455f0_row2_col7" class="data row2 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_455f0_level0_row3" class="row_heading level0 row3" >omp</th>
#       <td id="T_455f0_row3_col0" class="data row3 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_455f0_row3_col1" class="data row3 col1" >25.3401</td>
#       <td id="T_455f0_row3_col2" class="data row3 col2" >1340.0514</td>
#       <td id="T_455f0_row3_col3" class="data row3 col3" >35.5360</td>
#       <td id="T_455f0_row3_col4" class="data row3 col4" >-0.0506</td>
#       <td id="T_455f0_row3_col5" class="data row3 col5" >2.1732</td>
#       <td id="T_455f0_row3_col6" class="data row3 col6" >2.1710</td>
#       <td id="T_455f0_row3_col7" class="data row3 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_455f0_level0_row4" class="row_heading level0 row4" >huber</th>
#       <td id="T_455f0_row4_col0" class="data row4 col0" >Huber Regressor</td>
#       <td id="T_455f0_row4_col1" class="data row4 col1" >25.4028</td>
#       <td id="T_455f0_row4_col2" class="data row4 col2" >1345.1622</td>
#       <td id="T_455f0_row4_col3" class="data row4 col3" >35.6616</td>
#       <td id="T_455f0_row4_col4" class="data row4 col4" >-0.0653</td>
#       <td id="T_455f0_row4_col5" class="data row4 col5" >1.9698</td>
#       <td id="T_455f0_row4_col6" class="data row4 col6" >1.9320</td>
#       <td id="T_455f0_row4_col7" class="data row4 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_455f0_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_455f0_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_455f0_row5_col1" class="data row5 col1" >25.4635</td>
#       <td id="T_455f0_row5_col2" class="data row5 col2" >1351.4492</td>
#       <td id="T_455f0_row5_col3" class="data row5 col3" >35.7278</td>
#       <td id="T_455f0_row5_col4" class="data row5 col4" >-0.0658</td>
#       <td id="T_455f0_row5_col5" class="data row5 col5" >2.1074</td>
#       <td id="T_455f0_row5_col6" class="data row5 col6" >2.4908</td>
#       <td id="T_455f0_row5_col7" class="data row5 col7" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_455f0_level0_row6" class="row_heading level0 row6" >lar</th>
#       <td id="T_455f0_row6_col0" class="data row6 col0" >Least Angle Regression</td>
#       <td id="T_455f0_row6_col1" class="data row6 col1" >25.4635</td>
#       <td id="T_455f0_row6_col2" class="data row6 col2" >1351.4490</td>
#       <td id="T_455f0_row6_col3" class="data row6 col3" >35.7278</td>
#       <td id="T_455f0_row6_col4" class="data row6 col4" >-0.0658</td>
#       <td id="T_455f0_row6_col5" class="data row6 col5" >2.1074</td>
#       <td id="T_455f0_row6_col6" class="data row6 col6" >2.4908</td>
#       <td id="T_455f0_row6_col7" class="data row6 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_455f0_
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# Transformation Pipeline and Model Successfully Saved
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# <style type="text/css">
# #T_50948_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_50948">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50948_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_50948_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50948_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50948_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_50948_row0_col1" class="data row0 col1" >3137</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_50948_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_50948_row1_col1" class="data row1 col1" >return_r_label</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_50948_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_50948_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_50948_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_50948_row3_col1" class="data row3 col1" >(396, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_50948_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_50948_row4_col1" class="data row4 col1" >(277, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_50948_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_50948_row5_col1" class="data row5 col1" >(119, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_50948_row6_col0" class="data row6 col0" >Numeric features</td>
#       <td id="T_50948_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_50948_row7_col0" class="data row7 col0" >Categorical features</td>
#       <td id="T_50948_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_50948_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_50948_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_50948_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_50948_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_50948_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_50948_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_50948_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_50948_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_50948_row12_col0" class="data row12 col0" >Maximum one-hot encoding</td>
#       <td id="T_50948_row12_col1" class="data row12 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_50948_row13_col0" class="data row13 col0" >Encoding method</td>
#       <td id="T_50948_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_50948_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_50948_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_50948_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_50948_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_50948_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_50948_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_50948_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_50948_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_50948_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_50948_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_50948_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_50948_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_50948_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_50948_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_50948_row20_col1" class="data row20 col1" >358a</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d62fc th {
#   text-align: left;
# }
# ...
#     </tr>
#     <tr>
#       <th id="T_d71e3_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_d71e3_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_d71e3_row4_col1" class="data row4 col1" >39.0283</td>
#       <td id="T_d71e3_row4_col2" class="data row4 col2" >2822.3468</td>
#       <td id="T_d71e3_row4_col3" class="data row4 col3" >52.9410</td>
#       <td id="T_d71e3_row4_col4" class="data row4 col4" >-0.0467</td>
#       <td id="T_d71e3_row4_col5" class="data row4 col5" >2.0822</td>
#       <td id="T_d71e3_row4_col6" class="data row4 col6" >1.2942</td>
#       <td id="T_d71e3_row4_col7" class="data row4 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_d71e3_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_d71e3_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_d71e3_row5_col1" class="data row5 col1" >38.8278</td>
#       <td id="T_d71e3_row5_col2" class="data row5 col2" >2818.7583</td>
#       <td id="T_d71e3_row5_col3" class="data row5 col3" >52.9307</td>
#       <td id="T_d71e3_row5_col4" class="data row5 col4" >-0.0472</td>
#       <td id="T_d71e3_row5_col5" class="data row5 col5" >1.7419</td>
#       <td id="T_d71e3_row5_col6" class="data row5 col6" >1.4116</td>
#       <td id="T_d71e3_row5_col7" class="data row5 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_d71e3_level0_row6" class="row_heading level0 row6" >par</th>
#       <td id="T_d71e3_row6_col0" class="data row6 col0" >Passive Aggressive Regressor</td>
#       <td id="T_d71e3_row6_col1" class="data row6 col1" >40.8312</td>
#       <td id="T_d71e3_row6_col2" class="data row6 col2" >3047.0000</td>
#       <td id="T_d71e3_row6_col3" class="data row6 col3" >55.0008</td>
#       <td id="T_d71e3_row6_col4" class="data row6 col4" >-0.1389</td>
#       <td id="T_d71e3_row6_col5" class="data row6 col5" >1.7546</td>
#       <td id="T_d71e3_row6_col6" class="data row6 col6" >2.0768</td>
#       <td id="T_d71e3_row6_col7" class="data row6 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_d71e3_
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# Transformation Pipeline and Model Successfully Saved
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# <style type="text/css">
# #T_b1364_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b1364">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1364_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b1364_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1364_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1364_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b1364_row0_col1" class="data row0 col1" >2421</td>
#     </tr>
#     <tr>
#       <th id="T_b1364_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b1364_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b1364_row1_col1" class="data row1 col1" >return_r_label</td>
#     </tr>
#     <tr>
#       <th id="T_b1364_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b1364_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b1364_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_b1364_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b1364_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_b1364_row3_col1" class="data row3 col1" >(396, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_b1364_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b1364_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_b1364_row4_col1" class="data row4 col1" >(277, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_b1364_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b1364_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_b1364_row5_col1" class="data row5 col1" >(119, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_b1364_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b1364_row6_col0" class="data row6 col0" >Numeric features</td>
#       <td id="T_b1364_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b1364_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b1364_row7_col0" class="data row7 col0" >Categorical features</td>
#       <td id="T_b1364_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b1364_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b1364_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_b1364_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b1364_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b1364_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_b1364_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b1364_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b1364_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_b1364_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b1364_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b1364_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_b1364_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b1364_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b1364_row12_col0" class="data row12 col0" >Maximum one-hot encoding</td>
#       <td id="T_b1364_row12_col1" class="data row12 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_b1364_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b1364_row13_col0" class="data row13 col0" >Encoding method</td>
#       <td id="T_b1364_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b1364_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b1364_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T
row6_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e1e8d_row0_col7, #T_e1e8d_row4_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_e1e8d_row1_col7, #T_e1e8d_row2_col7, #T_e1e8d_row3_col7, #T_e1e8d_row5_col7, #T_e1e8d_row6_col7, #T_e1e8d_row7_col7, #T_e1e8d_row8_col7, #T_e1e8d_row9_col7, #T_e1e8d_row10_col7, #T_e1e8d_row11_col7, #T_e1e8d_row12_col7, #T_e1e8d_row13_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e1e8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1e8d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e1e8d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e1e8d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e1e8d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e1e8d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e1e8d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e1e8d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e1e8d_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1e8d_level0_row0" class="row_heading level0 row0" >omp</th>
#       <td id="T_e1e8d_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_e1e8d_row0_col1" class="data row0 col1" >17.4180</td>
#       <td id="T_e1e8d_row0_col2" class="data row0 col2" >553.7250</td>
#       <td id="T_e1e8d_row0_col3" class="data row0 col3" >23.1176</td>
#       <td id="T_e1e8d_row0_col4" class="data row0 col4" >-0.0118</td>
#       <td id="T_e1e8d_row0_col5" class="data row0 col5" >1.8258</td>
#       <td id="T_e1e8d_row0_col6" class="data row0 col6" >1.2620</td>
#       <td id="T_e1e8d_row0_col7" class="data row0 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_e1e8d_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_e1e8d_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_e1e8d_row1_col1" class="data row1 col1" >17.3897</td>
#       <td id="T_e1e8d_row1_col2" class="data row1 col2" >554.6562</td>
#       <td id="T_e1e8d_row1_col3" class="data row1 col3" >23.1339</td>
#       <td id="T_e1e8d_row1_col4" class="data row1 col4" >-0.0130</td>
#       <td id="T_e1e8d_row1_col5" class="data row1 col5" >1.8540</td>
#       <td id="T_e1e8d_row1_col6" class="data row1 col6" >1.2720</td>
#       <td id="T_e1e8d_row1_col7" class="data row1 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_e1e8d_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_e1e8d_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_e1e8d_row2_col1" class="data row2 col1" >17.4923</td>
#       <td id="T_e1e8d_row2_col2" class="data row2 col2" >558.3340</td>
#       <td id="T_e1e8d_row2_col3" class="data row2 col3" >23.2391</td>
#       <td id="T_e1e8d_row2_col4" class="data row2 col4" >-0.0254</td>
#       <td id="T_e1e8d_row2_col5" class="data row2 col5" >2.0378</td>
#       <td id="T_e1e8d_row2_col6" class="data row2 col6" >1.0843</td>
#       <td id="T_e1e8d_row2_col7" class="data row2 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_e1e8d_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_e1e8d_row3_col0" class="data row3 col0" >Linear Regression</td>
#       <td id="T_e1e8d_row3_col1" class="data row3 col1" >17.4681</td>
#       <td id="T_e1e8d_row3_col2" class="data row3 col2" >558.7855</td>
#       <td id="T_e1e8d_row3_col3" class="data row3 col3" >23.2473</td>
#       <td id="T_e1e8d_row3_col4" class="data row3 col4" >-0.0266</td>
#       <td id="T_e1e8d_row3_col5" class="data row3 col5" >1.8267</td>
#       <td id="T_e1e8d_row3_col6" class="data row3 col6" >1.2853</td>
#       <td id="T_e1e8d_row3_col7" class="data row3 col7" >0.0350</td>
#     </tr>
#     <tr>
#       <th id="T_e1e8d_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_e1e8d_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_e1e8d_row4_col1" class="data row4 col1" >17.4681</td>
#       <td id="T_e1e8d_row4_col2" class="data row4 col2" >558.7855</td>
#       <td id="T_e1e8d_row4_col3" class="data row4 col3" >23.2473</td>
#       <td id="T_e1e8d_row4_col4" class="data row4 col4" >-0.0266</td>
#       <td id="T_e1e8d_row4_col5" class="data row4 col5" >1.8267</td>
#       <td id="T_e1e8d_row4_col6" class="data row4 col6" >1.2853</td>
#       <td id="T_e1e8d_row4_col7" class="data row4 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_e1e8d_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_e1e8d_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_e1e8d_row5_col1" class="data row5 col1" >17.4936</td>
#       <td id="T_e1e8d_row5_col2" class="data row5 col2" >560.2345</td>
#       <td id="T_e1e8d_row5_col3" class="data row5 col3" >23.2815</td>
#       <td id="T_e1e8d_row5_col4" class="data row5 col4" >-0.0303</td>
#       <td id="T_e1e8d_row5_col5" class="data row5 col5" >1.7895</td>
#       <td id="T_e1e8d_row5_col6" class="data row5 col6" >1.4610</td>
#       <td id="T_e1e8d_row5_col7" class="data row5 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_e1e8d_level0_row6" class="row_heading level0 row6" >par</th>
#       <td id="T_e1e8d_row6_col0" class="data row6 col0" >Passive Aggressive Regressor</td>
#       <td id="T_e1e8d_row6_col1" class="data row6 col1" >19.1252</td>
#       <td id="T_e1e8d_row6_col2" class="data row6 col2" >654.8266</td>
#       <td id="T_e1e8d_row6_col3" class="data row6 col3" >24.9716</td>
#       <td id="T_e1e8d_row6_col4" class="data row6 col4" >-0.1757</td>
#       <td id="T_e1e8d_row6_col5" class="data row6 col5" >1.1400</td>
#       <td id="T_e1e8d_row6_col6" class="data row6 col6" >2.8570</td>
#       <td id="T_e1e8d_row6_col7" class="data row6 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_e1e8d_level0_
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# Transformation Pipeline and Model Successfully Saved

# %%
# check and see our dictionary
dic_vol
# Out:
# {'EURUSD': [0.0004281211142476265, 0.0004281211142476265],
#  'GBPUSD': [0.0004966384844507656, 0.0004966384844507656],
#  'USDCHF': [0.00042780905428066956, 0.00042780905428066956],
#  'USDCAD': [0.0003699360646692225, 0.0003699360646692225],
#  'USDHKD': [6.876542096790575e-05, 6.876542096790575e-05],
#  'USDAUD': [0.000666613601077178, 0.000666613601077178],
#  'USDNZD': [0.0005482998171061228, 0.0005482998171061228],
#  'USDSGD': [0.0002951453297140402, 0.0002951453297140402]}

# %%
dic_fd
# Out:
# {'EURUSD': [853594.7712419365, 1547680.8777432258],
#  'GBPUSD': [666361.329745896, 1212260.5721637346],
#  'USDCHF': [944561.0899999292, 2031250.0000000827],
#  'USDCAD': [866338.8172116696, 1776093.2312128684],
#  'USDHKD': [877566.5399239843, 10200033.39031332],
#  'USDAUD': [592503.5178437203, 1376526.7708181816],
#  'USDNZD': [294972.55499312916, 670718.232044248],
#  'USDSGD': [1299890.5394999508, 2774999.999998765]}
